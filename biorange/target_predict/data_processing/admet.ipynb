# %%
# %pip install admet_ai
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 3.2 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 3.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 3.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 3.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 3.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 21.5 MB/s eta 0:00:00
# ...

# %%
# %%capture
from admet_ai import ADMETModel
import pandas as pd

model = ADMETModel()
smiles=pd.read_csv("/home/liuyan/projects/package/biorange/biorange/data/TCM_NGM_ISOMERIC_SMILES.csv")
preds = model.predict(smiles= smiles.iloc[:,0].to_list())

#preds.to_csv('tcm_NGM_ISOMERIC_SMILES_ADMET.csv')
#ok我现在有个问题，咋调数量限制来着

# %%
# Out:
#                                                     molecular_weight    logP  \
# COC1=CC=C(C=C1)C2=COC3=C(C2=O)C=CC(=C3)O                     268.268  3.1742
# C1=CC=C(C=C1)C2=C(C(=O)C3=CC=CC=C3O2)O                       238.242  3.1656
# C1=CC(=CC=C1C2=CC(=O)C3=C(O2)C=C(C(=C3O)[C@H]4[...           432.381  0.0917
# CC(=C)[C@H]1CC2=C(O1)C=CC3=C2O[C@@H]4COC5=CC(=C...           394.423  3.7033
# C1=CC(=C(C=C1/C=C/C(=O)C2=C(C=C(C=C2)O)O)O)O                 272.256  2.4051
# COC1=CC(=C2C(=C1)OC(=C(C2=O)O)C3=CC(=C(C=C3)O)O)O            316.265  2.2910
# C[C@H]1[C@@H]([C@H]([C@H]([C@@H](O1)OC[C@@H]2[C...           740.664 -2.8920
# C1=CC2=C(C=C1O)OC3=C2C(=O)OC4=C3C=CC(=C4)O                   268.224  3.1036
# C1[C@@H]2[C@H](C3=C(O1)C=C(C=C3)O)OC4=CC5=C(C=C...           284.267  2.7306
# COC1=CC(=C2C(=C1)OC=C(C2=O)C3=CC=C(C=C3)O)O                  284.267  2.8798
#
#                                                     hydrogen_bond_acceptors  \
# ...

# %%
#用smlies号匹配出admet数据集中的相关信息
